# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.preprocessing import image
from tqdm import tqdm
from keras.layers import  BatchNormalization
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
from keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
from collections import Counter
import os.path
from os import path
import os
from os import listdir
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
from keras.models import model_from_json

# %% [markdown]
# ## Rename and resize all the data

# %%
 

#      206

folder_dir = "D:/UNI/5/ML/project/206"
i = 1000
for images in os.listdir(folder_dir):
     
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg") or images.endswith(".jpeg")):
        new =folder_dir + "/" + str(i) + ".jpg"
        i+=1
        old = folder_dir + "/" + images
        os.rename(old, new)
        
    
    
#      dena

folder_dir = "D:/UNI/5/ML/project/dena"
i = 2000
for images in os.listdir(folder_dir):
     
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg") or images.endswith(".jpeg")):
        new =folder_dir + "/" + str(i) + ".jpg"
        i+=1
        old = folder_dir + "/" + images
        os.rename(old, new)
        
        
#     pars

folder_dir = "D:/UNI/5/ML/project/pars"
i = 3000
for images in os.listdir(folder_dir):
     
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg") or images.endswith(".jpeg")):
        new =folder_dir + "/" + str(i) + ".jpg"
        i+=1
        old = folder_dir + "/" + images
        os.rename(old, new)
        
        
        
#      pride

folder_dir = "D:/UNI/5/ML/project/pride"
i = 4000
for images in os.listdir(folder_dir):
     
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg") or images.endswith(".jpeg")):
        new =folder_dir + "/" + str(i) + ".jpg"
        i+=1
        old = folder_dir + "/" + images
        os.rename(old, new)
        

#      samand

folder_dir = "D:/UNI/5/ML/project/samand"
i = 5000
for images in os.listdir(folder_dir):
     
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg") or images.endswith(".jpeg")):
        new =folder_dir + "/" + str(i) + ".jpg"
        i+=1
        old = folder_dir + "/" + images
        os.rename(old, new)
        
        
        
        
#      tiba

folder_dir = "D:/UNI/5/ML/project/tiba"
i = 6000
for images in os.listdir(folder_dir):
     
    # check if the image ends with png or jpg or jpeg
    if (images.endswith(".png") or images.endswith(".jpg") or images.endswith(".jpeg")):
        new =folder_dir + "/" + str(i) + ".jpg"
        i+=1
        old = folder_dir + "/" + images
        os.rename(old, new)

# %%
#      206

folder_dir = "D:/UNI/5/ML/project/206"
i = 1000

for i in range(1_000,1950):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img.save(folder_dir + "/" + str(i) + ".jpg")


#      dena

folder_dir = "D:/UNI/5/ML/project/dena"
i = 2000

for i in range(2_000,2950):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img.save(folder_dir + "/" + str(i) + ".jpg")        
        
        
        
#      pars

folder_dir = "D:/UNI/5/ML/project/pars"
i = 3000

for i in range(3_000,3950):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img.save(folder_dir + "/" + str(i) + ".jpg")
        
        
#      pride

folder_dir = "D:/UNI/5/ML/project/pride"
i = 4000

for i in range(4_000,4950):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img.save(folder_dir + "/" + str(i) + ".jpg")
        
        
#      samand

folder_dir = "D:/UNI/5/ML/project/samand"
i = 5000

for i in range(5_000,5950):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img.save(folder_dir + "/" + str(i) + ".jpg")
        
        
#      tiba

folder_dir = "D:/UNI/5/ML/project/tiba"
i = 6000

for i in range(6_000,6950):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img.save(folder_dir + "/" + str(i) + ".jpg")

# %% [markdown]
# ## read image

# %%
x = []

#      206

folder_dir = "D:/UNI/5/ML/project/206"
i = 1000
for i in tqdm(range(1_000,1950)):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img_to_array(img)
        img = img/255.
        x.append(img)
        
        
#      dena

folder_dir = "D:/UNI/5/ML/project/dena"
i = 2000
for i in tqdm(range(2_000,2950)):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img_to_array(img)
        img = img/255.
        x.append(img)
        
        
#      pars

folder_dir = "D:/UNI/5/ML/project/pars"
i = 3000
for i in tqdm(range(3_000,3950)):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img_to_array(img)
        img = img/255.
        x.append(img)
        
        
#      pride

folder_dir = "D:/UNI/5/ML/project/pride"
i = 4000
for i in tqdm(range(4_000,4950)):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img_to_array(img)
        img = img/255.
        x.append(img)
        
        
#      samand

folder_dir = "D:/UNI/5/ML/project/samand"
i = 5000
for i in tqdm(range(5_000,5950)):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img_to_array(img)
        img = img/255.
        x.append(img)



#      tiba

folder_dir = "D:/UNI/5/ML/project/tiba"
i = 6000
for i in tqdm(range(6_000,6950)):
    image_path = folder_dir + "/" + str(i) + ".jpg"

    if path.exists(image_path):
        img = load_img(image_path, target_size=(100,100,3)) 
        img = img_to_array(img)
        img = img/255.
        x.append(img)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 950/950 [00:02<00:00, 401.68it/s]
#
# 100%|███████████████████████████████████████████████████████████████████████████████| 950/950 [00:02<00:00, 390.65it/s]
#
# 100%|███████████████████████████████████████████████████████████████████████████████| 950/950 [00:02<00:00, 378.08it/s]
#
# 100%|███████████████████████████████████████████████████████████████████████████████| 950/950 [00:02<00:00, 403.81it/s]
#
# 100%|███████████████████████████████████████████████████████████████████████████████| 950/950 [00:02<00:00, 402.59it/s]
#
# 100%|███████████████████████████████████████████████████████████████████████████████| 950/950 [00:02<00:00, 390.43it/s]

# %% [markdown]
# ## label of images

# %%
df = pd.read_csv('D:/UNI/5/ML/project/data.csv', index_col = 0)

df
# Out:
#        206  dena  pars  pride  samand  tiba
# index
# 1000     1     0     0      0       0     0
# 1001     1     0     0      0       0     0
# 1002     1     0     0      0       0     0
# 1003     1     0     0      0       0     0
# 1004     1     0     0      0       0     0
# ...    ...   ...   ...    ...     ...   ...
# 6945     0     0     0      0       0     1
# 6946     0     0     0      0       0     1
# 6947     0     0     0      0       0     1
# 6948     0     0     0      0       0     1
# 6949     0     0     0      0       0     1
#
# [5700 rows x 6 columns]

# %% [markdown]
# ## split data to train, validation and test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, df, test_size=0.15,random_state=4)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.34)


x_test = np.array(x_test)
x_train = np.array(x_train)
x_val = np.array(x_val)
y_val = np.array(y_val)
y_test = np.array(y_test)
y_train = np.array(y_train)

# %% [markdown]
# # Define models

# %%
#Defining the Convolutional Neural Network
cnn_model = Sequential()

cnn_model.add(Conv2D(32, (3, 3), input_shape = (100,100,3), activation='relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Dropout(0.25))

cnn_model.add(Conv2D(64, (3, 3),  activation='relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Dropout(0.25))

cnn_model.add(Conv2D(128, (3, 3),  activation='relu'))
cnn_model.add(MaxPooling2D(pool_size = (2, 2)))
cnn_model.add(Dropout(0.25))

cnn_model.add(Flatten())
cnn_model.add(Dense(units = 512, activation = 'relu'))
cnn_model.add(Dropout(0.25))
cnn_model.add(Dense(units = 6, activation = 'softmax'))

# cnn_model.summary()

# %%
with mlflow.start_run():
    #Compiling
    cnn_model.compile(loss ='categorical_crossentropy', optimizer='adam' ,metrics =['accuracy'])
    history = cnn_model.fit(x_train, y_train, epochs=1, validation_data=(x_val, y_val), batch_size=64)
# Out:
# 76/76 [==============================] - 23s 292ms/step - loss: 1.7606 - accuracy: 0.2103 - val_loss: 1.6978 - val_accuracy: 0.3138

# %% [markdown]
# ## best result

# %%
# Building the model
model1 = Sequential()
# 3 convolutional layers
model1.add(Conv2D(32, (3, 3), input_shape = (100,100,3)))
model1.add(Activation("relu"))
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Conv2D(64, (3, 3)))
model1.add(Activation("relu"))
model1.add(MaxPooling2D(pool_size=(2,2)))


model1.add(Conv2D(64, (3, 3)))
model1.add(Activation("relu"))
model1.add(MaxPooling2D(pool_size=(2,2)))
model1.add(Dropout(0.9))

# 5 hidden layers
model1.add(Flatten())

model1.add(Dense(128))
model1.add(Activation("relu"))

model1.add(Dense(128))
model1.add(Activation("relu"))

model1.add(Dense(128))
model1.add(Activation("relu"))

model1.add(Dense(128))
model1.add(Activation("relu"))

model1.add(Dense(128))
model1.add(Activation("relu"))

# The output layer with 7 neurons, for 7 classes
model1.add(Dense(6))
model1.add(Activation("softmax"))

# Compiling the model using some basic parameters
model1.compile(loss='categorical_crossentropy',
                optimizer="adam",
                metrics=["accuracy"])

# %%
history1 = model1.fit(x_train, y_train, epochs=40, validation_data=(x_val, y_val), batch_size=16)


# #plot the training and validation accuracy and loss at each epoch
# loss = history.history['loss']
# val_loss = history.history['val_loss']
# epochs = range(1, len(loss) + 1)
# plt.plot(epochs, loss, 'y', label='Training loss')
# plt.plot(epochs, val_loss, 'r', label='Validation loss')
# plt.title('Training and validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

metrics_df = pd.DataFrame(history1.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model1.evaluate(x_test, y_test, verbose=2)
# predictions = cnn4.predict(x_test)
# predictions
# Out:
# Epoch 1/40
#
# 303/303 [==============================] - 18s 58ms/step - loss: 1.7941 - accuracy: 0.1688 - val_loss: 1.7894 - val_accuracy: 0.1560
#
# Epoch 2/40
#
# 303/303 [==============================] - 18s 59ms/step - loss: 1.7563 - accuracy: 0.2147 - val_loss: 1.7456 - val_accuracy: 0.2092
#
# Epoch 3/40
#
# 303/303 [==============================] - 18s 58ms/step - loss: 1.6991 - accuracy: 0.2497 - val_loss: 1.6813 - val_accuracy: 0.2411
#
# Epoch 4/40
#
# 303/303 [==============================] - 18s 58ms/step - loss: 1.6774 - accuracy: 0.2568 - val_loss: 1.6894 - val_accuracy: 0.2358
#
# Epoch 5/40
#
# 303/303 [==============================] - 18s 58ms/step - loss: 1.6572 - accuracy: 0.2710 - val_loss: 1.6611 - val_accuracy: 0.2996
#
# Epoch 6/40
#
# 303/303 [==============================] - 18s 58ms/step - loss: 1.6432 - accuracy: 0.2929 - val_loss: 1.6666 - val_accuracy: 0.2465
#
# Epoch 7/40
#
# ...

# %%
# Building the model
model2 = Sequential()
# 3 convolutional layers
model2.add(Conv2D(32, (3, 3), input_shape = (100,100,3)))
model2.add(Activation("relu"))
model2.add(MaxPooling2D(pool_size=(2,2)))

model2.add(Conv2D(64, (3, 3)))
model2.add(Activation("relu"))
model2.add(MaxPooling2D(pool_size=(2,2)))


model2.add(Conv2D(64, (3, 3)))
model2.add(Activation("relu"))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(Dropout(0.9))

# 5 hidden layers
model2.add(Flatten())

model2.add(Dense(128))
model2.add(Activation("relu"))

model2.add(Dense(128))
model2.add(Activation("relu"))

model2.add(Dense(128))
model2.add(Activation("relu"))

model2.add(Dense(128))
model2.add(Activation("relu"))

model2.add(Dense(128))
model2.add(Activation("relu"))

# The output layer with 7 neurons, for 7 classes
model2.add(Dense(6))
model2.add(Activation("softmax"))

# Compiling the model using some basic parameters
model2.compile(loss='categorical_crossentropy',
                optimizer="adam",
                metrics=["accuracy"])

# %%
history2 = model2.fit(x_train, y_train, epochs=40, validation_data=(x_val, y_val), batch_size=32)

metrics_df = pd.DataFrame(history2.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model2.evaluate(x_test, y_test, verbose=2)
# predictions = cnn4.predict(x_test)
# predictions
# Out:
# Epoch 1/40
#
# 152/152 [==============================] - 17s 107ms/step - loss: 1.7935 - accuracy: 0.1589 - val_loss: 1.7907 - val_accuracy: 0.1649
#
# Epoch 2/40
#
# 152/152 [==============================] - 17s 110ms/step - loss: 1.7582 - accuracy: 0.2153 - val_loss: 1.7434 - val_accuracy: 0.2039
#
# Epoch 3/40
#
# 152/152 [==============================] - 18s 121ms/step - loss: 1.7045 - accuracy: 0.2448 - val_loss: 1.6932 - val_accuracy: 0.2376
#
# Epoch 4/40
#
# 152/152 [==============================] - 19s 122ms/step - loss: 1.6764 - accuracy: 0.2603 - val_loss: 1.7122 - val_accuracy: 0.2535
#
# Epoch 5/40
#
# 152/152 [==============================] - 19s 122ms/step - loss: 1.6592 - accuracy: 0.2768 - val_loss: 1.6727 - val_accuracy: 0.2660
#
# Epoch 6/40
#
# 152/152 [==============================] - 17s 111ms/step - loss: 1.6400 - accuracy: 0.2813 - val_loss: 1.6385 - val_accuracy: 0.2926
#
# Epoch 7/40
#
# ...

# %%
# Building the model
model3 = Sequential()
# 3 convolutional layers
model3.add(Conv2D(32, (3, 3), input_shape = (100,100,3)))
model3.add(Activation("relu"))
model3.add(MaxPooling2D(pool_size=(2,2)))

model3.add(Conv2D(64, (3, 3)))
model3.add(Activation("relu"))
model3.add(MaxPooling2D(pool_size=(2,2)))


model3.add(Conv2D(128, (3, 3)))
model3.add(Activation("relu"))
model3.add(MaxPooling2D(pool_size=(2,2)))
model3.add(Dropout(0.9))

# 5 hidden layers
model3.add(Flatten())

model3.add(Dense(128))
model3.add(Activation("relu"))

model3.add(Dense(128))
model3.add(Activation("relu"))

model3.add(Dense(128))
model3.add(Activation("relu"))

model3.add(Dense(128))
model3.add(Activation("relu"))

model3.add(Dense(128))
model3.add(Activation("relu"))

# The output layer with 7 neurons, for 7 classes
model3.add(Dense(6))
model3.add(Activation("softmax"))

# Compiling the model using some basic parameters
model3.compile(loss='categorical_crossentropy',
                optimizer="adam",
                metrics=["accuracy"])

# %%
history3 = model3.fit(x_train, y_train, epochs=40, validation_data=(x_val, y_val), batch_size=64)


metrics_df = pd.DataFrame(history3.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model3.evaluate(x_test, y_test, verbose=2)
# Out:
# Epoch 1/40
#
# 76/76 [==============================] - 18s 237ms/step - loss: 1.7935 - accuracy: 0.1734 - val_loss: 1.7900 - val_accuracy: 0.2358
#
# Epoch 2/40
#
# 76/76 [==============================] - 18s 242ms/step - loss: 1.7513 - accuracy: 0.2211 - val_loss: 1.7262 - val_accuracy: 0.2057
#
# Epoch 3/40
#
# 76/76 [==============================] - 19s 249ms/step - loss: 1.6860 - accuracy: 0.2508 - val_loss: 1.6817 - val_accuracy: 0.2660
#
# Epoch 4/40
#
# 76/76 [==============================] - 19s 244ms/step - loss: 1.6627 - accuracy: 0.2720 - val_loss: 1.6551 - val_accuracy: 0.2589
#
# Epoch 5/40
#
# 76/76 [==============================] - 18s 239ms/step - loss: 1.6243 - accuracy: 0.2987 - val_loss: 1.6238 - val_accuracy: 0.3050
#
# Epoch 6/40
#
# 76/76 [==============================] - 18s 234ms/step - loss: 1.5751 - accuracy: 0.3352 - val_loss: 1.6230 - val_accuracy: 0.3245
#
# Epoch 7/40
#
# ...

# %%
history_temp = model3.fit(x_train, y_train, epochs=20, validation_data=(x_val, y_val), batch_size=64)


# #plot the training and validation accuracy and loss at each epoch
# loss = history.history['loss']
# val_loss = history.history['val_loss']
# epochs = range(1, len(loss) + 1)
# plt.plot(epochs, loss, 'y', label='Training loss')
# plt.plot(epochs, val_loss, 'r', label='Validation loss')
# plt.title('Training and validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

metrics_df = pd.DataFrame(history_temp.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model3.evaluate(x_test, y_test, verbose=2)
# predictions = cnn4.predict(x_test)
# predictions
# Out:
# Epoch 1/20
#
# 76/76 [==============================] - 15s 194ms/step - loss: 0.7555 - accuracy: 0.7160 - val_loss: 0.9452 - val_accuracy: 0.6720
#
# Epoch 2/20
#
# 76/76 [==============================] - 15s 198ms/step - loss: 0.7466 - accuracy: 0.7232 - val_loss: 1.0425 - val_accuracy: 0.6082
#
# Epoch 3/20
#
# 76/76 [==============================] - 15s 197ms/step - loss: 0.7358 - accuracy: 0.7245 - val_loss: 0.9311 - val_accuracy: 0.6525
#
# Epoch 4/20
#
# 76/76 [==============================] - 15s 198ms/step - loss: 0.7285 - accuracy: 0.7288 - val_loss: 0.9647 - val_accuracy: 0.6684
#
# Epoch 5/20
#
# 76/76 [==============================] - 17s 224ms/step - loss: 0.7224 - accuracy: 0.7296 - val_loss: 1.0021 - val_accuracy: 0.6365
#
# Epoch 6/20
#
# 76/76 [==============================] - 17s 219ms/step - loss: 0.7214 - accuracy: 0.7352 - val_loss: 0.9791 - val_accuracy: 0.6543
#
# Epoch 7/20
#
# ...

# %%
metrics_df = pd.DataFrame(history_temp.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model3.evaluate(x_test, y_test, verbose=2)
# Out:
# 10/10 - 0s - loss: 0.8245 - accuracy: 0.7045 - 273ms/epoch - 27ms/step

# %%
history_t  = history3

history_t.history.update(history_temp.history)

# %%
metrics_df = pd.DataFrame(history3.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model3.evaluate(x_test, y_test, verbose=2)
# Out:
# 10/10 - 0s - loss: 0.8245 - accuracy: 0.7045 - 250ms/epoch - 25ms/step

# %%
# Building the model
model4 = Sequential()
# 3 convolutional layers
model4.add(Conv2D(32, (3, 3), input_shape = (100,100,3)))
model4.add(Activation("relu"))
model4.add(MaxPooling2D(pool_size=(2,2)))

model4.add(Conv2D(64, (3, 3)))
model4.add(Activation("relu"))
model4.add(MaxPooling2D(pool_size=(2,2)))


model4.add(Conv2D(64, (3, 3)))
model4.add(Activation("relu"))
model4.add(MaxPooling2D(pool_size=(2,2)))
model4.add(Dropout(0.9))

# 5 hidden layers
model4.add(Flatten())

model4.add(Dense(128))
model4.add(Activation("relu"))

model4.add(Dense(128))
model4.add(Activation("relu"))

model4.add(Dense(128))
model4.add(Activation("relu"))

model4.add(Dense(128))
model4.add(Activation("relu"))

model4.add(Dense(128))
model4.add(Activation("relu"))

# The output layer with 7 neurons, for 7 classes
model4.add(Dense(6))
model4.add(Activation("softmax"))

# Compiling the model using some basic parameters
model4.compile(loss='categorical_crossentropy',
                optimizer="adam",
                metrics=["accuracy"])

# %%
history4 = model4.fit(x_train, y_train, epochs=40, validation_data=(x_val, y_val), batch_size=128)


metrics_df = pd.DataFrame(history4.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model4.evaluate(x_test, y_test, verbose=2)
# Out:
# Epoch 1/40
#
# 38/38 [==============================] - 17s 422ms/step - loss: 1.7954 - accuracy: 0.1637 - val_loss: 1.7919 - val_accuracy: 0.1543
#
# Epoch 2/40
#
# 38/38 [==============================] - 15s 404ms/step - loss: 1.7909 - accuracy: 0.1740 - val_loss: 1.7928 - val_accuracy: 0.1649
#
# Epoch 3/40
#
# 38/38 [==============================] - 16s 411ms/step - loss: 1.7742 - accuracy: 0.1955 - val_loss: 1.7460 - val_accuracy: 0.2394
#
# Epoch 4/40
#
# 38/38 [==============================] - 15s 404ms/step - loss: 1.7191 - accuracy: 0.2497 - val_loss: 1.7113 - val_accuracy: 0.2394
#
# Epoch 5/40
#
# 38/38 [==============================] - 16s 422ms/step - loss: 1.6789 - accuracy: 0.2615 - val_loss: 1.6708 - val_accuracy: 0.2748
#
# Epoch 6/40
#
# 38/38 [==============================] - 16s 413ms/step - loss: 1.6447 - accuracy: 0.2834 - val_loss: 1.6438 - val_accuracy: 0.3014
#
# Epoch 7/40
#
# ...

# %%
# Building the model
model5 = Sequential()
# 3 convolutional layers
model5.add(Conv2D(32, (3, 3), input_shape = (100,100,3)))
model5.add(Activation("relu"))
model5.add(MaxPooling2D(pool_size=(2,2)))

model5.add(Conv2D(64, (3, 3)))
model5.add(Activation("relu"))
model5.add(MaxPooling2D(pool_size=(2,2)))


model5.add(Conv2D(64, (3, 3)))
model5.add(Activation("relu"))
model5.add(MaxPooling2D(pool_size=(2,2)))
model5.add(Dropout(0.9))

# 5 hidden layers
model5.add(Flatten())

model5.add(Dense(128))
model5.add(Activation("relu"))

model5.add(Dense(128))
model5.add(Activation("relu"))

model5.add(Dense(128))
model5.add(Activation("relu"))

model5.add(Dense(128))
model5.add(Activation("relu"))

model5.add(Dense(128))
model5.add(Activation("relu"))

# The output layer with 7 neurons, for 7 classes
model5.add(Dense(6))
model5.add(Activation("softmax"))

# Compiling the model using some basic parameters
model5.compile(loss='categorical_crossentropy',
                optimizer="adam",
                metrics=["accuracy"])

# %%
history5 = model5.fit(x_train, y_train, epochs=80, validation_data=(x_val, y_val), batch_size=64)


metrics_df = pd.DataFrame(history5.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model5.evaluate(x_test, y_test, verbose=2)
# predictions = cnn4.predict(x_test)
# predictions
# Out:
# Epoch 1/80
#
# 76/76 [==============================] - 17s 214ms/step - loss: 1.7940 - accuracy: 0.1608 - val_loss: 1.7915 - val_accuracy: 0.1667
#
# Epoch 2/80
#
# 76/76 [==============================] - 16s 206ms/step - loss: 1.7763 - accuracy: 0.2037 - val_loss: 1.7411 - val_accuracy: 0.2057
#
# Epoch 3/80
#
# 76/76 [==============================] - 15s 204ms/step - loss: 1.7222 - accuracy: 0.2330 - val_loss: 1.7129 - val_accuracy: 0.2500
#
# Epoch 4/80
#
# 76/76 [==============================] - 16s 204ms/step - loss: 1.6823 - accuracy: 0.2592 - val_loss: 1.7092 - val_accuracy: 0.2766
#
# Epoch 5/80
#
# 76/76 [==============================] - 16s 207ms/step - loss: 1.6614 - accuracy: 0.2642 - val_loss: 1.6738 - val_accuracy: 0.2482
#
# Epoch 6/80
#
# 76/76 [==============================] - 16s 207ms/step - loss: 1.6439 - accuracy: 0.2774 - val_loss: 1.6354 - val_accuracy: 0.2926
#
# Epoch 7/80
#
# ...

# %%
history_t = model5.fit(x_train, y_train, epochs=80, validation_data=(x_val, y_val), batch_size=64)



metrics_df = pd.DataFrame(history_t.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model5.evaluate(x_test, y_test, verbose=2)
# predictions = cnn4.predict(x_test)
# predictions
# Out:
# Epoch 1/80
#
# 76/76 [==============================] - 15s 198ms/step - loss: 0.4521 - accuracy: 0.8353 - val_loss: 0.9787 - val_accuracy: 0.6879
#
# Epoch 2/80
#
# 76/76 [==============================] - 15s 196ms/step - loss: 0.4714 - accuracy: 0.8248 - val_loss: 0.9843 - val_accuracy: 0.6915
#
# Epoch 3/80
#
# 76/76 [==============================] - 15s 201ms/step - loss: 0.4760 - accuracy: 0.8324 - val_loss: 1.0312 - val_accuracy: 0.6826
#
# Epoch 4/80
#
# 76/76 [==============================] - 16s 205ms/step - loss: 0.4704 - accuracy: 0.8250 - val_loss: 0.9912 - val_accuracy: 0.7004
#
# Epoch 5/80
#
# 76/76 [==============================] - 15s 203ms/step - loss: 0.4574 - accuracy: 0.8314 - val_loss: 0.9959 - val_accuracy: 0.7039
#
# Epoch 6/80
#
# 76/76 [==============================] - 16s 205ms/step - loss: 0.4800 - accuracy: 0.8225 - val_loss: 1.0271 - val_accuracy: 0.6755
#
# Epoch 7/80
#
# ...

# %%
# Building the model
model6 = Sequential()
# 3 convolutional layers
model6.add(Conv2D(32, (3, 3), input_shape = (100,100,3)))
model6.add(Activation("relu"))
model6.add(MaxPooling2D(pool_size=(2,2)))

model6.add(Conv2D(64, (3, 3)))
model6.add(Activation("relu"))
model6.add(MaxPooling2D(pool_size=(2,2)))


model6.add(Conv2D(64, (3, 3)))
model6.add(Activation("relu"))
model6.add(MaxPooling2D(pool_size=(2,2)))
model6.add(Dropout(0.9))

# 5 hidden layers
model6.add(Flatten())

model6.add(Dense(128))
model6.add(Activation("relu"))

model6.add(Dense(128))
model6.add(Activation("relu"))

model6.add(Dense(128))
model6.add(Activation("relu"))

model6.add(Dense(128))
model6.add(Activation("relu"))

model6.add(Dense(128))
model6.add(Activation("relu"))

# The output layer with 7 neurons, for 7 classes
model6.add(Dense(6))
model6.add(Activation("softmax"))

# Compiling the model using some basic parameters
model6.compile(loss='categorical_crossentropy',
                optimizer="adam",
                metrics=["accuracy"])

# %%
with mlflow.start_run():

    history6 = model6.fit(x_train, y_train, epochs=350, validation_data=(x_val, y_val), batch_size=256)
    metrics_df = pd.DataFrame(history6.history)
    test_loss, test_acc = model6.evaluate(x_test, y_test, verbose=2)
    
    mlflow.log_metrics({
        'train_loss':float(metrics_df["loss"].iloc[-1:]),
        'val_loss':float(metrics_df["val_loss"].iloc[-1:]),
        'train_accuracy':float(metrics_df["accuracy"].iloc[-1:]),
        'val_accuracy':float(metrics_df["val_accuracy"].iloc[-1:]),
        'test_loss': test_loss,
        'test_accuracy':test_acc
    })
    mlflow.log_param("batch_size", 256)
    mlflow.log_param("epochs", 200)
    
    
    metrics_df[["loss","val_loss"]].plot()
    metrics_df[["accuracy","val_accuracy"]].plot()
# Out:
# Epoch 1/350
#
# 19/19 [==============================] - 16s 809ms/step - loss: 1.7946 - accuracy: 0.1604 - val_loss: 1.7926 - val_accuracy: 0.1649
#
# Epoch 2/350
#
# 19/19 [==============================] - 15s 777ms/step - loss: 1.7912 - accuracy: 0.1796 - val_loss: 1.7902 - val_accuracy: 0.1560
#
# Epoch 3/350
#
# 19/19 [==============================] - 15s 787ms/step - loss: 1.7748 - accuracy: 0.1802 - val_loss: 1.7476 - val_accuracy: 0.2305
#
# Epoch 4/350
#
# 19/19 [==============================] - 15s 782ms/step - loss: 1.7209 - accuracy: 0.2421 - val_loss: 1.7095 - val_accuracy: 0.2589
#
# Epoch 5/350
#
# 19/19 [==============================] - 15s 817ms/step - loss: 1.6859 - accuracy: 0.2563 - val_loss: 1.6771 - val_accuracy: 0.2518
#
# Epoch 6/350
#
# 19/19 [==============================] - 15s 809ms/step - loss: 1.6731 - accuracy: 0.2578 - val_loss: 1.6726 - val_accuracy: 0.2784
#
# Epoch 7/350
#
# ...

# %%
model6_prime = Sequential()
# 3 convolutional layers
model6_prime.add(Conv2D(32, (3, 3), input_shape = (100,100,3)))
model6_prime.add(Activation("relu"))
model6_prime.add(MaxPooling2D(pool_size=(2,2)))

model6_prime.add(Conv2D(64, (3, 3)))
model6_prime.add(Activation("relu"))
model6_prime.add(MaxPooling2D(pool_size=(2,2)))


model6_prime.add(Conv2D(128, (3, 3)))
model6_prime.add(Activation("relu"))
model6_prime.add(MaxPooling2D(pool_size=(2,2)))
model6_prime.add(Dropout(0.9))

# 5 hidden layers
model6_prime.add(Flatten())

model6_prime.add(Dense(128))
model6_prime.add(Activation("relu"))

model6_prime.add(Dense(128))
model6_prime.add(Activation("relu"))

model6_prime.add(Dense(128))
model6_prime.add(Activation("relu"))

model6_prime.add(Dense(128))
model6_prime.add(Activation("relu"))

model6_prime.add(Dense(128))
model6_prime.add(Activation("relu"))

# The output layer with 7 neurons, for 7 classes
model6_prime.add(Dense(6))
model6_prime.add(Activation("softmax"))

# Compiling the model using some basic parameters
model6_prime.compile(loss='categorical_crossentropy',
                optimizer="adam",
                metrics=["accuracy"])

# %%
with mlflow.start_run():

    history6_prime = model6_prime.fit(x_train, y_train, epochs=350, validation_data=(x_val, y_val), batch_size=256)
    metrics_df = pd.DataFrame(history6_prime.history)
    test_loss, test_acc = model6_prime.evaluate(x_test, y_test, verbose=2)
    
    mlflow.log_metrics({
        'train_loss':float(metrics_df["loss"].iloc[-1:]),
        'val_loss':float(metrics_df["val_loss"].iloc[-1:]),
        'train_accuracy':float(metrics_df["accuracy"].iloc[-1:]),
        'val_accuracy':float(metrics_df["val_accuracy"].iloc[-1:]),
        'test_loss': test_loss,
        'test_accuracy':test_acc
    })
    mlflow.log_param("batch_size", 256)
    mlflow.log_param("epochs", 200)
    
    
    metrics_df[["loss","val_loss"]].plot()
    metrics_df[["accuracy","val_accuracy"]].plot()
# Out:
# Epoch 1/350
#
# 19/19 [==============================] - 17s 884ms/step - loss: 1.7953 - accuracy: 0.1591 - val_loss: 1.7921 - val_accuracy: 0.1507
#
# Epoch 2/350
#
# 19/19 [==============================] - 16s 864ms/step - loss: 1.7920 - accuracy: 0.1715 - val_loss: 1.7911 - val_accuracy: 0.1613
#
# Epoch 3/350
#
# 19/19 [==============================] - 16s 856ms/step - loss: 1.7885 - accuracy: 0.1963 - val_loss: 1.7764 - val_accuracy: 0.2039
#
# Epoch 4/350
#
# 19/19 [==============================] - 16s 861ms/step - loss: 1.7444 - accuracy: 0.2341 - val_loss: 1.7253 - val_accuracy: 0.2447
#
# Epoch 5/350
#
# 19/19 [==============================] - 16s 853ms/step - loss: 1.7051 - accuracy: 0.2584 - val_loss: 1.6870 - val_accuracy: 0.2677
#
# Epoch 6/350
#
# 19/19 [==============================] - 16s 856ms/step - loss: 1.6808 - accuracy: 0.2782 - val_loss: 1.6733 - val_accuracy: 0.2872
#
# Epoch 7/350
#
# ...

# %%
with mlflow.start_run():

    history6_t = model6.fit(x_train, y_train, epochs=100, validation_data=(x_val, y_val), batch_size=256)
    metrics_df = pd.DataFrame(history6_t.history)
    test_loss, test_acc = model6.evaluate(x_test, y_test, verbose=2)
    
    mlflow.log_metrics({
        'train_loss':float(metrics_df["loss"].iloc[-1:]),
        'val_loss':float(metrics_df["val_loss"].iloc[-1:]),
        'train_accuracy':float(metrics_df["accuracy"].iloc[-1:]),
        'val_accuracy':float(metrics_df["val_accuracy"].iloc[-1:]),
        'test_loss': test_loss,
        'test_accuracy':test_acc
    })
    mlflow.log_param("batch_size", 256)
    mlflow.log_param("epochs", 200)
    
    metrics_df[["loss","val_loss"]].plot()
    metrics_df[["accuracy","val_accuracy"]].plot()
# Out:
# Epoch 1/40
#
# 19/19 [==============================] - 16s 833ms/step - loss: 0.8241 - accuracy: 0.6916 - val_loss: 0.9999 - val_accuracy: 0.6418
#
# Epoch 2/40
#
# 19/19 [==============================] - 16s 824ms/step - loss: 0.8095 - accuracy: 0.7001 - val_loss: 1.0031 - val_accuracy: 0.6383
#
# Epoch 3/40
#
# 19/19 [==============================] - 16s 845ms/step - loss: 0.7812 - accuracy: 0.7094 - val_loss: 0.9449 - val_accuracy: 0.6631
#
# Epoch 4/40
#
# 19/19 [==============================] - 16s 818ms/step - loss: 0.7832 - accuracy: 0.7094 - val_loss: 0.9381 - val_accuracy: 0.6436
#
# Epoch 5/40
#
# 19/19 [==============================] - 15s 813ms/step - loss: 0.7864 - accuracy: 0.7059 - val_loss: 0.9343 - val_accuracy: 0.6702
#
# Epoch 6/40
#
# 19/19 [==============================] - 16s 855ms/step - loss: 0.7562 - accuracy: 0.7160 - val_loss: 0.9793 - val_accuracy: 0.6418
#
# Epoch 7/40
#
# ...

# %%
history6_tt = model6.fit(x_train, y_train, epochs=40, validation_data=(x_val, y_val), batch_size=256)



metrics_df = pd.DataFrame(history6_tt.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = model6.evaluate(x_test, y_test, verbose=2)
# Out:
# Epoch 1/40
#
# 19/19 [==============================] - 15s 807ms/step - loss: 0.4950 - accuracy: 0.8204 - val_loss: 0.8951 - val_accuracy: 0.7128
#
# Epoch 2/40
#
# 19/19 [==============================] - 15s 794ms/step - loss: 0.4803 - accuracy: 0.8285 - val_loss: 0.9360 - val_accuracy: 0.6986
#
# Epoch 3/40
#
# 19/19 [==============================] - 15s 798ms/step - loss: 0.4990 - accuracy: 0.8169 - val_loss: 0.9503 - val_accuracy: 0.6773
#
# Epoch 4/40
#
# 19/19 [==============================] - 16s 818ms/step - loss: 0.4777 - accuracy: 0.8223 - val_loss: 0.8922 - val_accuracy: 0.6986
#
# Epoch 5/40
#
# 19/19 [==============================] - 16s 828ms/step - loss: 0.4704 - accuracy: 0.8293 - val_loss: 0.9049 - val_accuracy: 0.6933
#
# Epoch 6/40
#
# 19/19 [==============================] - 16s 821ms/step - loss: 0.4616 - accuracy: 0.8268 - val_loss: 0.9231 - val_accuracy: 0.6968
#
# Epoch 7/40
#
# ...

# %%
with mlflow.start_run():

    history6_ttt = model6.fit(x_train, y_train, epochs=40, validation_data=(x_val, y_val), batch_size=256)

    metrics_df = pd.DataFrame(history6_ttt.history)
    metrics_df[["loss","val_loss"]].plot()
    metrics_df[["accuracy","val_accuracy"]].plot()

    test_loss, test_acc = model6.evaluate(x_test, y_test, verbose=2)
# Out:
# Epoch 1/40
#
# 19/19 [==============================] - 15s 813ms/step - loss: 0.3577 - accuracy: 0.8665 - val_loss: 0.9540 - val_accuracy: 0.7057
#
# Epoch 2/40
#
# 19/19 [==============================] - 16s 862ms/step - loss: 0.3641 - accuracy: 0.8691 - val_loss: 0.9745 - val_accuracy: 0.6897
#
# Epoch 3/40
#
# 19/19 [==============================] - 15s 803ms/step - loss: 0.3483 - accuracy: 0.8749 - val_loss: 0.8932 - val_accuracy: 0.7145
#
# Epoch 4/40
#
# 19/19 [==============================] - 16s 842ms/step - loss: 0.3185 - accuracy: 0.8892 - val_loss: 0.9210 - val_accuracy: 0.7110
#
# Epoch 5/40
#
# 19/19 [==============================] - 17s 859ms/step - loss: 0.3282 - accuracy: 0.8846 - val_loss: 0.9469 - val_accuracy: 0.7004
#
# Epoch 6/40
#
# 19/19 [==============================] - 17s 896ms/step - loss: 0.3242 - accuracy: 0.8811 - val_loss: 0.9595 - val_accuracy: 0.7074
#
# Epoch 7/40
#
# ...

# %%
with mlflow.start_run():

    history6_tttt = model6.fit(x_train, y_train, epochs=1, validation_data=(x_val, y_val), batch_size=256)

    metrics_df = pd.DataFrame(history6_tttt.history)
    test_loss, test_acc = model6.evaluate(x_test, y_test, verbose=2)
    mlflow.log_metrics({
        'train_loss':float(metrics_df["loss"].iloc[-1:]),
        'val_loss':float(metrics_df["val_loss"].iloc[-1:]),
        'train_accuracy':float(metrics_df["accuracy"].iloc[-1:]),
        'val_accuracy':float(metrics_df["val_accuracy"].iloc[-1:]),
        'test_loss': test_loss,
        'test_accuracy':test_acc
    })
    mlflow.log_param("batch_size", 256)
    mlflow.log_param("epochs", 1)
# Out:
# 19/19 [==============================] - 15s 808ms/step - loss: 0.2467 - accuracy: 0.9129 - val_loss: 1.0344 - val_accuracy: 0.7163
#
# 10/10 - 0s - loss: 0.8223 - accuracy: 0.7457 - 236ms/epoch - 24ms/step

# %%
combo_acc=np.concatenate((history6_tttt.history['accuracy'],combo_acc),axis=0)
combo_val_acc=np.concatenate((history6_tttt.history['val_accuracy'],combo_val_acc),axis=0)

plt.plot(combo_acc, 'orange', label='Training accuracy')
plt.plot(combo_val_acc, 'blue', label='Validation accuracy')
plt.legend()

# %% [markdown]
# # Bad result

# %% [markdown]
# ## Alex Net

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import time


model_AlexNet = keras.models.Sequential([
    keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(100,100,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(4096, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(6, activation='softmax')
])



# model4.compile(loss='categorical_crossentropy',
#                 optimizer="adam",
#                 metrics=["accuracy"])
# Out:
# D:\programming\ML\ML_learning\notebook\roshan\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#
#   super(SGD, self).__init__(name, **kwargs)

# %% [markdown]
# ## VGGNet

# %%
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

model_vgg = Sequential()
model_vgg.add(Conv2D(input_shape=(100,100,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model_vgg.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model_vgg.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model_vgg.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model_vgg.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model_vgg.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model_vgg.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model_vgg.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model_vgg.add(Flatten())
model_vgg.add(Dense(units=4096,activation="relu"))
model_vgg.add(Dense(units=4096,activation="relu"))
model_vgg.add(Dense(units=6, activation="softmax"))

model_vgg.compile(loss='categorical_crossentropy',
                optimizer="adam",
                metrics=["accuracy"])

# %%
history = model_vgg.fit(x_train, y_train, epochs=20, validation_data=(x_val, y_val), batch_size=32)


#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
#
# 152/152 [==============================] - 362s 2s/step - loss: 1.7974 - accuracy: 0.1666 - val_loss: 1.7919 - val_accuracy: 0.1649
#
# Epoch 2/20
#
# 152/152 [==============================] - 330s 2s/step - loss: 1.7921 - accuracy: 0.1622 - val_loss: 1.7918 - val_accuracy: 0.1649
#
# Epoch 3/20
#
# 152/152 [==============================] - 328s 2s/step - loss: 1.7919 - accuracy: 0.1651 - val_loss: 1.7918 - val_accuracy: 0.1649
#
# Epoch 4/20
#
# 152/152 [==============================] - 328s 2s/step - loss: 1.7919 - accuracy: 0.1527 - val_loss: 1.7918 - val_accuracy: 0.1560
#
# Epoch 5/20
#
# 152/152 [==============================] - 328s 2s/step - loss: 1.7919 - accuracy: 0.1643 - val_loss: 1.7918 - val_accuracy: 0.1649
#
# Epoch 6/20
#
# 152/152 [==============================] - 327s 2s/step - loss: 1.7919 - accuracy: 0.1585 - val_loss: 1.7918 - val_accuracy: 0.1560
#
# Epoch 7/20
#
# ...

# %% [markdown]
# ## GoogleNet

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, GlobalAveragePooling2D, Dense, Dropout
from keras.layers import concatenate

def Inception_block(input_layer, f1, f2_conv1, f2_conv3, f3_conv1, f3_conv5, f4): 
  # Input: 
  # - f1: number of filters of the 1x1 convolutional layer in the first path
  # - f2_conv1, f2_conv3 are number of filters corresponding to the 1x1 and 3x3 convolutional layers in the second path
  # - f3_conv1, f3_conv5 are the number of filters corresponding to the 1x1 and 5x5  convolutional layer in the third path
  # - f4: number of filters of the 1x1 convolutional layer in the fourth path

  # 1st path:
  path1 = Conv2D(filters=f1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)

  # 2nd path
  path2 = Conv2D(filters = f2_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path2 = Conv2D(filters = f2_conv3, kernel_size = (3,3), padding = 'same', activation = 'relu')(path2)

  # 3rd path
  path3 = Conv2D(filters = f3_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path3 = Conv2D(filters = f3_conv5, kernel_size = (5,5), padding = 'same', activation = 'relu')(path3)

  # 4th path
  path4 = MaxPooling2D((3,3), strides= (1,1), padding = 'same')(input_layer)
  path4 = Conv2D(filters = f4, kernel_size = (1,1), padding = 'same', activation = 'relu')(path4)

  output_layer = concatenate([path1, path2, path3, path4], axis = -1)

  return output_layer



def GoogLeNet():
  # input layer 
  input_layer = Input(shape = (100, 100, 3))

  # convolutional layer: filters = 64, kernel_size = (7,7), strides = 2
  X = Conv2D(filters = 64, kernel_size = (7,7), strides = 2, padding = 'valid', activation = 'relu')(input_layer)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # convolutional layer: filters = 64, strides = 1
  X = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding = 'same', activation = 'relu')(X)

  # convolutional layer: filters = 192, kernel_size = (3,3)
  X = Conv2D(filters = 192, kernel_size = (3,3), padding = 'same', activation = 'relu')(X)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 1st Inception block
  X = Inception_block(X, f1 = 64, f2_conv1 = 96, f2_conv3 = 128, f3_conv1 = 16, f3_conv5 = 32, f4 = 32)

  # 2nd Inception block
  X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 192, f3_conv1 = 32, f3_conv5 = 96, f4 = 64)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 3rd Inception block
  X = Inception_block(X, f1 = 192, f2_conv1 = 96, f2_conv3 = 208, f3_conv1 = 16, f3_conv5 = 48, f4 = 64)

  # Extra network 1:
  X1 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X1 = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X1)
  X1 = Flatten()(X1)
  X1 = Dense(1024, activation = 'relu')(X1)
  X1 = Dropout(0.7)(X1)
  X1 = Dense(5, activation = 'softmax')(X1)

  
  # 4th Inception block
  X = Inception_block(X, f1 = 160, f2_conv1 = 112, f2_conv3 = 224, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

  # 5th Inception block
  X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 256, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

  # 6th Inception block
  X = Inception_block(X, f1 = 112, f2_conv1 = 144, f2_conv3 = 288, f3_conv1 = 32, f3_conv5 = 64, f4 = 64)

  # Extra network 2:
  X2 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X2 = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X2)
  X2 = Flatten()(X2)
  X2 = Dense(1024, activation = 'relu')(X2)
  X2 = Dropout(0.7)(X2)
  X2 = Dense(1000, activation = 'softmax')(X2)
  
  
  # 7th Inception block
  X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, 
                      f3_conv5 = 128, f4 = 128)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # 8th Inception block
  X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, f3_conv5 = 128, f4 = 128)

  # 9th Inception block
  X = Inception_block(X, f1 = 384, f2_conv1 = 192, f2_conv3 = 384, f3_conv1 = 48, f3_conv5 = 128, f4 = 128)

  # Global Average pooling layer 
  X = GlobalAveragePooling2D(name = 'GAPL')(X)

  # Dropoutlayer 
  X = Dropout(0.4)(X)

  # output layer 
  X = Dense(6, activation = 'softmax')(X)
  
  # model
  model = Model(input_layer, [X, X1, X2], name = 'GoogLeNet')

  return model

# %%
model_googleNet = GoogLeNet()

# %% [markdown]
# ## ResNet

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

def identity_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x

def convolutional_block(x, filter):
    # copy tensor to variable called x_skip
    x_skip = x
    # Layer 1
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same', strides = (2,2))(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    x = tf.keras.layers.Activation('relu')(x)
    # Layer 2
    x = tf.keras.layers.Conv2D(filter, (3,3), padding = 'same')(x)
    x = tf.keras.layers.BatchNormalization(axis=3)(x)
    # Processing Residue with conv(1,1)
    x_skip = tf.keras.layers.Conv2D(filter, (1,1), strides = (2,2))(x_skip)
    # Add Residue
    x = tf.keras.layers.Add()([x, x_skip])     
    x = tf.keras.layers.Activation('relu')(x)
    return x


def ResNet34(shape = (100, 100, 3), classes = 6):
    # Step 1 (Setup Input Layer)
    x_input = tf.keras.layers.Input(shape)
    x = tf.keras.layers.ZeroPadding2D((3, 3))(x_input)
    # Step 2 (Initial Conv layer along with maxPool)
    x = tf.keras.layers.Conv2D(64, kernel_size=7, strides=2, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding='same')(x)
    # Define size of sub-blocks and initial filter size
    block_layers = [3, 4, 6, 3]
    filter_size = 64
    # Step 3 Add the Resnet Blocks
    for i in range(4):
        if i == 0:
            # For sub-block 1 Residual/Convolutional block not needed
            for j in range(block_layers[i]):
                x = identity_block(x, filter_size)
        else:
            # One Residual/Convolutional Block followed by Identity blocks
            # The filter size will go on increasing by a factor of 2
            filter_size = filter_size*2
            x = convolutional_block(x, filter_size)
            for j in range(block_layers[i] - 1):
                x = identity_block(x, filter_size)
    # Step 4 End Dense Network
    x = tf.keras.layers.AveragePooling2D((2,2), padding = 'same')(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(512, activation = 'relu')(x)
    x = tf.keras.layers.Dense(classes, activation = 'softmax')(x)
    model = tf.keras.models.Model(inputs = x_input, outputs = x, name = "ResNet34")
    return model

# %%
model_resNet = ResNet34()

# %%
model_resNet.compile(loss='categorical_crossentropy',
                optimizer="sgd",
                metrics=["accuracy"])
history = model_resNet.fit(x_train, y_train, epochs=20, validation_data=(x_val, y_val), batch_size=32)


#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
#
# 152/152 [==============================] - 150s 976ms/step - loss: 2.0963 - accuracy: 0.1922 - val_loss: 1.8284 - val_accuracy: 0.1560
#
# Epoch 2/20
#
# 152/152 [==============================] - 156s 1s/step - loss: 1.6372 - accuracy: 0.3193 - val_loss: 1.9065 - val_accuracy: 0.1684
#
# Epoch 3/20
#
# 152/152 [==============================] - 149s 983ms/step - loss: 1.4431 - accuracy: 0.4285 - val_loss: 1.5501 - val_accuracy: 0.3794
#
# Epoch 4/20
#
# 152/152 [==============================] - 154s 1s/step - loss: 1.2154 - accuracy: 0.5335 - val_loss: 2.8419 - val_accuracy: 0.2429
#
# Epoch 5/20
#
# 152/152 [==============================] - 149s 981ms/step - loss: 0.9660 - accuracy: 0.6369 - val_loss: 3.8512 - val_accuracy: 0.2447
#
# Epoch 6/20
#
# 152/152 [==============================] - 155s 1s/step - loss: 0.7644 - accuracy: 0.7232 - val_loss: 2.0685 - val_accuracy: 0.3936
#
# Epoch 7/20
#
# ...

# %% [markdown]
# ## vgg19

# %%
from keras.applications import VGG19

# Create the base model of VGG19
vgg19 = VGG19( include_top=False, input_shape = (100, 100, 3), classes = 6)
# Out:
# ...
#
#  1474560/80134624 [..............................] - ETA: 34:19
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <cell line: 4>()
#       1 from keras.applications import VGG19
#       3 # Create the base model of VGG19
# ----> 4 vgg19 = VGG19( include_top=False, input_shape = (100, 100, 3), classes = 6)
#
# File D:\programming\ML\ML_learning\notebook\roshan\lib\site-packages\keras\applications\vgg19.py:222, in VGG19(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation)
#     216     weights_path = data_utils.get_file(
#     217         'vgg19_weights_tf_dim_ordering_tf_kernels.h5',
#     218         WEIGHTS_PATH,
#     219         cache_subdir='models',
#     220         file_hash='cbe5617147190e668d6c5d5026f83318')
#     221   else:
# --> 222     weights_path = data_utils.get_file(
# ...

# %%
from keras.applications.vgg19 import preprocess_input

# Preprocessing the input 
x_train = preprocess_input(x_train)
x_val = preprocess_input(x_val)
x_test = preprocess_input(x_test)

# %%
train_features = vgg19.predict(np.array(x_train), batch_size=32, verbose=1)
test_features = vgg19.predict(np.array(x_test), batch_size=32, verbose=1)
val_features = vgg19.predict(np.array(x_val), batch_size=32, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 train_features = vgg19.predict(np.array(x_train), batch_size=32, verbose=1)
#       2 test_features = vgg19.predict(np.array(x_test), batch_size=32, verbose=1)
#       3 val_features = vgg19.predict(np.array(x_val), batch_size=32, verbose=1)
#
# NameError: name 'vgg19' is not defined

# %%
from keras.layers import Dense, Dropout
from keras.models import Model
from keras import models
from keras import layers
from keras import optimizers

# Add Dense and Dropout layers on top of VGG19 pre-trained
model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_dim=4 * 4 * 512))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(6, activation="softmax"))



import keras

# Compile the model
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])



# Train the the model
history = model.fit(x_train, y_train,
          batch_size=32,
          epochs=20,
          verbose=1,
          validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [53], in <cell line: 25>()
#      18 model.compile(loss=keras.losses.categorical_crossentropy,
#      19               optimizer=keras.optimizers.Adam(),
#      20               metrics=['accuracy'])
#      24 # Train the the model
# ---> 25 history = model.fit(x_train, y_train,
#      26           batch_size=32,
#      27           epochs=20,
#      28           verbose=1,
#      29           validation_data=(x_val, y_val))
#
# File D:\programming\ML\ML_learning\notebook\roshan\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
# ...

# %% [markdown]
# ## 4-conv

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization

cnn4 = Sequential()
cnn4.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(100,100,3)))
cnn4.add(BatchNormalization())

cnn4.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(MaxPooling2D(pool_size=(2, 2)))
cnn4.add(Dropout(0.25))

cnn4.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(Dropout(0.25))

cnn4.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(MaxPooling2D(pool_size=(2, 2)))
cnn4.add(Dropout(0.25))

cnn4.add(Flatten())

cnn4.add(Dense(512, activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(Dropout(0.5))

cnn4.add(Dense(128, activation='relu'))
cnn4.add(BatchNormalization())
cnn4.add(Dropout(0.5))

cnn4.add(Dense(6, activation='softmax'))

# %%
cnn4.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

# %%
history4 = cnn4.fit(x_train, y_train,
          batch_size=32,
          epochs=20,
          verbose=1,
          validation_data=(x_val, y_val))

#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
#
# 152/152 [==============================] - 93s 604ms/step - loss: 2.4576 - accuracy: 0.2140 - val_loss: 6.2424 - val_accuracy: 0.1525
#
# Epoch 2/20
#
# 152/152 [==============================] - 91s 598ms/step - loss: 2.0614 - accuracy: 0.2528 - val_loss: 2.6064 - val_accuracy: 0.1950
#
# Epoch 3/20
#
# 152/152 [==============================] - 87s 572ms/step - loss: 1.7865 - accuracy: 0.3135 - val_loss: 2.2521 - val_accuracy: 0.1897
#
# Epoch 4/20
#
# 152/152 [==============================] - 87s 572ms/step - loss: 1.6439 - accuracy: 0.3540 - val_loss: 1.9138 - val_accuracy: 0.2340
#
# Epoch 5/20
#
# 152/152 [==============================] - 89s 589ms/step - loss: 1.5302 - accuracy: 0.4014 - val_loss: 1.8745 - val_accuracy: 0.3050
#
# Epoch 6/20
#
# 152/152 [==============================] - 87s 571ms/step - loss: 1.4037 - accuracy: 0.4559 - val_loss: 1.5209 - val_accuracy: 0.4060
#
# Epoch 7/20
#
# ...

# %%
metrics_df = pd.DataFrame(history4.history)
metrics_df[["loss","val_loss"]].plot()
metrics_df[["accuracy","val_accuracy"]].plot()

test_loss, test_acc = cnn4.evaluate(x_test, y_test, verbose=2)
predictions = cnn4.predict(x_test)
predictions
# Out:
# 10/10 - 1s - loss: 1.4702 - accuracy: 0.5739 - 847ms/epoch - 85ms/step
#
# 10/10 [==============================] - 1s 85ms/step
# array([[1.13023650e-02, 1.28127472e-03, 4.45857411e-03, 1.07370457e-02,
#         9.59029913e-01, 1.31908180e-02],
#        [4.07234058e-02, 9.16504383e-01, 1.01168081e-02, 2.48242781e-04,
#         2.22250037e-02, 1.01821534e-02],
#        [8.82331096e-03, 3.86986270e-04, 9.35091436e-01, 3.66027141e-03,
#         2.18960680e-02, 3.01418994e-02],
#        ...,
#        [2.31031820e-01, 2.00916361e-03, 5.28174758e-01, 9.07290503e-02,
#         1.36059344e-01, 1.19958455e-02],
#        [9.83270288e-01, 5.22027863e-03, 1.07401675e-02, 4.53489018e-04,
#         2.96623854e-04, 1.92102216e-05],
#        [1.00832870e-02, 9.04261775e-04, 9.74426746e-01, 9.36500635e-03,
#         5.19919489e-03, 2.14137654e-05]], dtype=float32)
